# %% [markdown]
# <a href="https://colab.research.google.com/github/obabar/Omkar_RTR_2018/blob/master/First_Try.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Loading Library
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/equester/TataTelecomAI/master/Sample%20Data/asr_data.csv")

# %%
data.head(10)
# Out:
#    acd  col3  mos  noattempts  answercall  asr
# 0  118     9    5        1454  484.666667   72
# 1   92     1    1        1161  387.000000   86
# 2   12     1    1        1730  576.666667   18
# 3   92     4    2        1322  440.666667   90
# 4   21     3    4        1990  663.333333   44
# 5   66     9    2        1797  599.000000    8
# 6   30     4    3        1930  643.333333   29
# 7   59     1    2        1270  423.333333   67
# 8   92    10    2        1486  495.333333   65
# 9   17     8    3        1164  388.000000   86

# %%
#histogram
data['acd'].hist()

# %%
data['acd'].mean()
# Out:
# 51.46488294314381

# %%
sns.jointplot("noattempts", "answercall", data=data, kind='reg')
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/axes/_axes.py:6571: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
sns.jointplot("mos", "asr", data=data, kind='reg')
